# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
from skimage.color import rgb2gray
import geomstats.geometry.discrete_curves
from geomstats.geometry.euclidean import Euclidean
from geomstats.geometry.discrete_curves import DiscreteCurves

from tqdm.notebook import tqdm

# %%
a = skimage.io.imread(r"C:\Users\17345\Documents\Manuscripts\FOCAPO_Paper\Code\Sand_Analysis\Kermit 20180501_40M.JPG")

b = rgb2gray(a)

# %%
from skimage.filters import sobel
elevation_map = sobel(b)

# %%
markers = np.zeros_like(b)
markers[b < .2] = 1
markers[b > .8] = 2

# %%
from skimage.segmentation import watershed
segmentation = watershed(elevation_map, markers)

# %%
plt.imshow(segmentation)

# %%
from skimage import measure

# Find contours at a constant value of 0.8
contours = measure.find_contours(segmentation, 1)


# Display the image and plot all contours found
fig, ax = plt.subplots()
ax.imshow(segmentation, cmap=plt.cm.gray)

for contour in contours:
    ax.plot(contour[:, 1], contour[:, 0], linewidth=2)

ax.axis('image')
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
for contour in contours:
    plt.plot(contour[:, 1], contour[:, 0], linewidth=2)

# %%
import geomstats.backend as gs

def interpolate(curve, nb_points):
    """Interpolate a discrete curve with nb_points from a discrete curve.

    Returns
    -------
    interpolation : discrete curve with nb_points points
    """
    old_length = curve.shape[0]
    interpolation = gs.zeros((nb_points, 2))
    incr = old_length / nb_points
    pos = 0
    for i in range(nb_points):
        index = int(gs.floor(pos))
        interpolation[i] = curve[index] + (pos - index) * (
            curve[(index + 1) % old_length] - curve[index]
        )
        pos += incr
    return interpolation


k_sampling_points = 1000

def preprocess(curve, tol=1e-10):
    """Preprocess curve to ensure that there are no consecutive duplicate points.

    Returns
    -------
    curve : discrete curve
    """

    dist = curve[1:] - curve[:-1]
    dist_norm = np.sqrt(np.sum(np.square(dist), axis=1))

    if np.any( dist_norm < tol ):
        for i in range(len(curve)-2):
            if np.sqrt(np.sum(np.square(curve[i+1] - curve[i]), axis=0)) < tol:
                curve[i+1] = (curve[i] + curve[i+2]) / 2

    return curve

def center(point):

    mean = gs.mean(point, axis=-2)
    
    return point - mean[..., None, :]

# %%
A1 = contours[6]
A2 = contours[43]

# %%
B2 = interpolate(A2,1000)
B1 = interpolate(A1,1000)

# %%
plt.plot(B2[:,0],B2[:,1])

# %%
from geomstats.geometry.pre_shape import PreShapeSpace

M_AMBIENT = 2

PRESHAPE_SPACE = PreShapeSpace(m_ambient=M_AMBIENT, k_landmarks=1000)
PRESHAPE_METRIC = PRESHAPE_SPACE.embedding_space.metric


curve = B1

base_curve = B2

nb_sampling = len(curve)

distances = gs.zeros(nb_sampling)

base_curve = gs.array(base_curve)

for shift in range(nb_sampling):
    reparametrized = [curve[(i + shift) % nb_sampling] for i in range(nb_sampling)]
    aligned = PRESHAPE_SPACE.align(point=gs.array(reparametrized), base_point=base_curve)
    distances[shift] = PRESHAPE_METRIC.norm(gs.array(aligned) - gs.array(base_curve))
    
shift_min = gs.argmin(distances)

reparametrized_min = [curve[(i + shift_min) % nb_sampling] for i in range(nb_sampling)]

aligned_curve = PRESHAPE_SPACE.align(point=gs.array(reparametrized_min), base_point=base_curve)

# %%
C1 = center(aligned_curve)
C2 = center(base_curve)

# %%
plt.plot(C1[:,0],C1[:,1])
plt.plot(C2[:,0],C2[:,1])

# %%
n_times = 10
times = gs.linspace(0.0, 1.0, n_times)

r2 = Euclidean(dim=2)

metric = geomstats.geometry.discrete_curves.SRVMetric(r2)

hgeod_fun = metric.geodesic(preprocess(C1), preprocess(C2))
hgeod = hgeod_fun(times)

# %%
plt.figure(figsize=(7, 7))
plt.plot(hgeod[0, :, 0], hgeod[0, :, 1], "b")
for i in range(1, n_times - 1):
    plt.plot(hgeod[i, :, 0], hgeod[i, :, 1], "k")
plt.plot(hgeod[-1, :, 0], hgeod[-1, :, 1], "r")
plt.title("Horizontal geodesic")
plt.show()

# %%
good = []

for i in contours:
    if (len(i[:,0]) > 200):
        good.append(i)

# %%
f = [0,1,15,16,23,26]

a_good = []

for i in range(26):
    if i not in f:
        a_good.append(good[i])

# %%
for i in a_good:
    plt.plot(i[:,0],i[:,1])

# %%
np.shape(a_good)
# Out:
# (21,)

# %%
dist = np.zeros((21,21))

for i in tqdm(range(21)):
    
    for j in tqdm(range(21)):
        
        B2 = interpolate(a_good[i],1000)
        B1 = interpolate(a_good[j],1000)
        
        curve = preprocess(B1)

        base_curve = preprocess(B2)

        nb_sampling = len(curve)

        distances = gs.zeros(nb_sampling)

        base_curve = gs.array(base_curve)

        for shift in range(nb_sampling):
            reparametrized = [curve[(i + shift) % nb_sampling] for i in range(nb_sampling)]
            aligned = PRESHAPE_SPACE.align(point=gs.array(reparametrized), base_point=base_curve)
            distances[shift] = PRESHAPE_METRIC.norm(gs.array(aligned) - gs.array(base_curve))

        shift_min = gs.argmin(distances)

        reparametrized_min = [curve[(i + shift_min) % nb_sampling] for i in range(nb_sampling)]

        aligned_curve = PRESHAPE_SPACE.align(point=gs.array(reparametrized_min), base_point=base_curve)
        
        C1 = center(aligned_curve)
        
        C2 = center(base_curve)
        
        hgeod_fun = metric.geodesic(preprocess(C1), preprocess(C2))
        
        print(metric.dist(C1,C2))
        
        dist[i,j] = metric.dist(C1,C2)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# 6.416172339467486e-12
# 18.377291428155687
# nan
# 17.855897172709934
# 15.90124702043827
# 16.625192446499522
# 16.233524795219363
# 17.419246140930184
# 16.085282728818505
# 16.960065117476752
# 16.603535266973036
# nan
# 16.076852032637735
# 19.62088890549325
# 18.11279618749224
# 18.441964112496827
# nan
# 15.769889783692795
# 16.91537627262514
# 17.609321348781407
# 16.73010272806063
#   0%|          | 0/21 [00:00<?, ?it/s]
# 18.37868358227016
# 5.625210805220152e-12
# nan
# 17.782005982421058
# 17.83166827164101
# 18.15161205138277
# 19.11156853480369
# 17.88519770604338
# 17.588491444668506
# 19.599165278370013
# 17.674518330193017
# nan
# 18.018151799505652
# 19.865068894395407
# 19.210671131185308
# 19.309988493256018
# nan
# 18.02914579264796
# 17.829908962588345
# 19.472301073397542
# 17.89543691050927
#   0%|          | 0/21 [00:00<?, ?it/s]
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#   0%|          | 0/21 [00:00<?, ?it/s]
# 17.85668854305004
# 17.779493142357307
# nan
# 4.07888361024804e-12
# 15.83951892436861
# 16.276954908580322
# 17.04767748096167
# 16.522746163102
# 16.563541390504437
# 16.378949696084113
# 16.039329385434943
# nan
# 15.74344711135019
# 16.686826288828264
# 16.43913183565241
# 15.22342964144016
# nan
# 16.73422403698996
# 14.181764898640633
# 17.16645732821223
# 15.433370732937746
#   0%|          | 0/21 [00:00<?, ?it/s]
# 15.895620550534085
# 17.82967256063587
# nan
# 15.835320092487796
# 3.034530828954342e-12
# 15.904417820542658
# 15.875768508358776
# 16.15263689156359
# 15.927694448690866
# 16.460912082323663
# 14.9520739823732
# nan
# 15.717744644718772
# 17.834896617444308
# 17.457322982718008
# 17.17878551042387
# nan
# 15.91339277226824
# 15.168201296611636
# 17.146733888616726
# 15.795558749366421
#   0%|          | 0/21 [00:00<?, ?it/s]
# 16.627896255484227
# 18.146058688857835
# nan
# 16.27661579502093
# 15.90776527691442
# 5.888653157721124e-12
# 17.42989385361467
# 16.75582716938369
# 16.295812398036503
# 17.354106963178992
# 16.347415838229008
# nan
# 16.43087873106341
# 17.87146479476709
# 18.708623554878017
# 17.547197457526405
# nan
# 16.440290058326344
# 15.764599789170195
# 17.22992774853818
# 15.820502397012262
#   0%|          | 0/21 [00:00<?, ?it/s]
# 16.23991084668812
# 19.110858343231307
# nan
# 17.047071639937542
# 15.878103554340363
# 17.415662675245095
# 6.007152929762883e-12
# 16.77759382534919
# 17.101589032786908
# 15.668064213712466
# 15.49504249170136
# nan
# 16.044232907048148
# 18.107712299008874
# 17.096226162419928
# 16.436506688567317
# nan
# 16.594598860447213
# 16.2577752444337
# 17.626116100968257
# 16.86127428217761
#   0%|          | 0/21 [00:00<?, ?it/s]
# 17.417727379919864
# 17.880206673840224
# nan
# 16.51708575028953
# 16.15501498931205
# 16.75347627876231
# 16.778201373875156
# 4.1068064701567775e-12
# 16.799867419999487
# 15.99727443000738
# 16.352115598087423
# nan
# 15.189948913121722
# 17.075711164178177
# 18.36855974111413
# 16.82955681862396
# nan
# 17.689498799989586
# 17.18773833849409
# 17.975187981627585
# 17.39342847285825
#   0%|          | 0/21 [00:00<?, ?it/s]
# 16.077141044739314
# 17.58228144255207
# nan
# 16.566532775122017
# 15.92882338563831
# 16.291389917886193
# 17.10204339367575
# 16.798609950401417
# 3.4211530515714e-12
# 16.683348522855283
# 15.146752601281714
# nan
# 16.313848497741347
# 17.820400050390273
# 18.74446592284184
# 16.855707221091283
# nan
# 16.192706900289295
# 16.25048628547174
# 17.669177474628682
# 15.23272168583612
#   0%|          | 0/21 [00:00<?, ?it/s]
# 16.970013509987762
# 19.597076442230357
# nan
# 16.383405055962598
# 16.46869374950689
# 17.367141545872656
# 15.669199566829146
# 15.999714799087656
# 16.68191881937558
# 6.079385056439957e-12
# 15.922256921200164
# nan
# 15.427065144279783
# 16.443511416022357
# 16.202457968778106
# 16.107098884127403
# nan
# 17.067511516996337
# 17.000115575916844
# 16.24073013943024
# 17.924817151177034
#   0%|          | 0/21 [00:00<?, ?it/s]
# 16.578748496609542
# 17.66997408650919
# nan
# 16.037709909288132
# 14.953821548881535
# 16.344665630963082
# 15.49396625984142
# 16.340621924041148
# 15.12907776296893
# 15.917242837929386
# 3.988243843936426e-12
# nan
# 15.681614692158838
# 18.43837954765132
# 16.71686063217887
# 16.141144780090954
# nan
# 15.039365585802488
# 15.054821257514572
# 17.153906355028703
# 15.787301100134536
#   0%|          | 0/21 [00:00<?, ?it/s]
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#   0%|          | 0/21 [00:00<?, ?it/s]
# 16.07626170100907
# 18.014056229495576
# nan
# nan
# 15.717053975081098
# 16.438534706385717
# 16.03798672116613
# 15.188469079642235
# 16.315547987937133
# 15.424999919919975
# 15.682921304452643
# nan
# 6.419944320058673e-12
# 16.471846416576046
# 15.12428003490281
# 15.498408634576041
# nan
# 16.89475781064041
# 15.690974875720768
# 17.262217393366896
# 16.76149540595318
#   0%|          | 0/21 [00:00<?, ?it/s]
# 19.62230987587823
# 19.859059141322778
# nan
# 16.69777202600458
# 17.834969710429604
# 17.858472809229124
# 18.10267240674597
# 17.085517425585877
# 17.80986808741514
# 16.455072352685313
# 18.44092625378361
# nan
# 16.46045831301044
# 4.81165103644823e-12
# 18.564374391075376
# 16.124869243633512
# nan
# 19.52543895073943
# 17.083765377557
# 18.499641832641228
# 17.934928650622293
#   0%|          | 0/21 [00:00<?, ?it/s]
# 18.11961683412314
# 19.21299867956568
# nan
# 16.444694540683635
# 17.45841149632458
# 18.711281447457488
# 17.091602400060506
# 18.374024558287974
# 18.747003947095287
# 16.20528596305439
# 16.714248413915954
# nan
# 15.127428492332376
# 18.558431029705947
# 6.548897763157746e-12
# 17.472015738064467
# nan
# 17.373534689474987
# 16.938679600613522
# 18.850222902030897
# 18.42531181326022
#   0%|          | 0/21 [00:00<?, ?it/s]
# 18.44245812765357
# 19.319370105309755
# nan
# 15.21865986433906
# 17.18130831224661
# 17.549517312235732
# 16.44070138958949
# 16.83470211227771
# 16.867449266266245
# 16.11066514499705
# 16.145430147114705
# nan
# 15.500819976969423
# 16.132245914812767
# 17.467800253420624
# 4.829427924541376e-12
# nan
# 18.16065330554693
# 16.7361785044245
# 18.018035430847476
# 17.060116098380504
#   0%|          | 0/21 [00:00<?, ?it/s]
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#   0%|          | 0/21 [00:00<?, ?it/s]
# 15.766480711141206
# 18.027322253741684
# nan
# 16.734261074723502
# 15.914114694964336
# 16.442572840317368
# 16.587979097272388
# 17.695866343308527
# 16.190898322476272
# 17.065370519054866
# 15.039498436564132
# nan
# 16.895837949234405
# 19.510369696628107
# 17.367632072614036
# 18.15117403597872
# nan
# 6.404615751509706e-12
# 15.958074993154712
# 17.79989396102001
# 16.218793713423448
#   0%|          | 0/21 [00:00<?, ?it/s]
# 16.919084645493896
# 17.82466856203342
# nan
# 14.182903317868936
# 15.159052418631454
# 15.757250100835282
# 16.259083023852167
# 17.18787070685706
# 16.251318402661884
# 16.996811509677702
# 15.047232858931016
# nan
# 15.69544358846766
# 17.073936131403386
# 16.944173956570665
# 16.73180925716442
# nan
# 15.95569392615798
# 7.626119140439086e-12
# 16.21299727882799
# 14.359853108378111
#   0%|          | 0/21 [00:00<?, ?it/s]
# 17.6140350395005
# 19.46795739005169
# nan
# 17.165917531469372
# 17.146926571134838
# 17.23168519618827
# 17.629281889894738
# 17.971723223029606
# 17.67456808105602
# 16.244934503335134
# 17.172238563325934
# nan
# 17.26671985346286
# 18.487735432510583
# 18.848224081096284
# 18.017765505274753
# nan
# 17.80433090732415
# 16.2075646299022
# 5.448213615361866e-12
# 16.4187649392935
#   0%|          | 0/21 [00:00<?, ?it/s]
# 16.730643124810577
# 17.895628135342363
# nan
# 15.446319393648954
# 15.79707419953759
# 15.816675905256885
# 16.859207475060316
# 17.39138943863928
# 15.234135957183584
# 17.923210255158278
# 15.78673244977387
# nan
# 16.774023097252318
# 17.939389888640708
# 18.421044061785047
# 17.055809278892163
# nan
# 16.216148964413893
# 14.360153283132654
# 16.414935363556204
# 9.107507740437405e-12

# %%
dist1 = np.array(dist)

# %%
dist1 = dist1[~np.isnan(dist1)]

# %%
np.shape(dist)
# Out:
# (21, 21)

# %%
a_del = np.delete(dist, [2,11,12,16], 0)

b_del = np.delete(a_del, [2,11,12,16], 1)

# %%
plt.imshow(b_del + b_del.T)

# %%
from sklearn.manifold import MDS

mds = MDS(dissimilarity = 'precomputed',n_components = 2)

X = mds.fit_transform(b_del + b_del.T)
# Out:
# C:\Users\17345\anaconda3\envs\particle_geometry\lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
plt.scatter(X[:,0],X[:,1])

# %%
np.argsort(X[:,0])
# Out:
# array([ 0, 13,  7,  4,  3, 16,  1, 11, 14,  9,  5,  2, 15,  8, 10, 12,  6],
#       dtype=int64)

# %%
plt.plot(a_good[0][:,0],a_good[0][:,1])
plt.plot(a_good[13][:,0],a_good[13][:,1])
plt.plot(a_good[7][:,0],a_good[7][:,1])

# %%
plt.plot(a_good[0][:,0],a_good[0][:,1],'r')
plt.plot(a_good[13][:,0],a_good[13][:,1],'r')


plt.plot(a_good[6][:,0],a_good[6][:,1],'b')
plt.plot(a_good[12][:,0],a_good[12][:,1],'b')


plt.plot(a_good[11][:,0],a_good[11][:,1],'g')
plt.plot(a_good[14][:,0],a_good[14][:,1],'g')
